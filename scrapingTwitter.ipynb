# %%
consumer_key = 'tiVIII7j3O9bPAbRgdJWmoJWd'
consumer_secret = 'SR5KZuyzFgXkXvd0tADD8qFDfYzQ0mXBaTTvgDq0SagnHlWLEU'
access_token = '490394724-yTbJ770PfbqAqdiejo8IfEEKkIKTTtmTNodZI0ru'
access_token_secret = '3qouPTCCnp6t1tfV6NjcXbJ4ulQ4wJ5WQt9QZzwURuTGo'

# %%
import tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
import time
tweets_list = []
text_query = 'McDonaldsFrance'
count = 100000
try:
# Pulling individual tweets from query
    for tweet in api.search(q=text_query, count=count):
# Adding to list that contains all tweets
        tweets.append((tweet.created_at,tweet.id,tweet.text))
except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)

# %%
import pandas as pd
df = pd.DataFrame(tweets, columns=['date','id','text'])

# %%
df.head()
# Out:
#                  date                   id  \
# 0 2020-05-01 20:38:13  1256322053226917889
# 1 2020-05-01 20:38:00  1256321997937598467
# 2 2020-05-01 20:37:11  1256321792752283648
# 3 2020-05-01 20:36:26  1256321605765959680
# 4 2020-05-01 20:36:20  1256321577831948288
#
#                                                 text
# 0  How many days until Election Day in US? https:...
# 1  RT @Frankadlingtons: US Presidential Election ...
# 2  US election: Hilary may replace Biden https://...
# 3  RT @SenWhitehouse: Each &amp; every one of the...
# 4  Hello everyone. I hope that everything is okay...

# %%
from wordcloud import WordCloud, STOPWORDS 
import sys,tweepy,csv,re
import matplotlib.pyplot as plt 
import pandas as pd 
  
from nltk.corpus import stopwords 
sp =stopwords.words('french')
comment_words = '' 
#stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.text: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = sp, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
import GetOldTweets3 as got

text_query = 'McDonalds France'
since_date = '2010-01-01'
until_date = '2019-12-31'
count = 200000
# Creation of query object
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setSince(since_date).setUntil(until_date).setMaxTweets(count)
# Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
# Creating list of chosen tweet data
text_tweets = [[tweet.date, tweet.text] for tweet in tweets]

# %%
import pandas as pd

tweets_df = pd.DataFrame(text_tweets, columns=['date','text'])

# %%
tweets_df['text']
# Out:
# 0       Au bout de l'absurde peut-être la victoire aus...
# 1       Bonne nouvelle ! De la vaisselle réutilisable ...
# 2       Domac Français : plus de Royal Cheese. Plus de...
# 3       Catégorie Culture & Loisirs | Effie Bronze @Mc...
# 4       Catégorie Communication Corporate | Effie OR @...
# 5       Catégorie Boissons | Effie Argent @McDonalds F...
# 6       French fries are eh in all of them. however id...
# 7       merci McDonalds France d’avoir supprimé les pa...
# 8       Ils font dans l'humour #mcdonalds maintenant ?...
# 9       mcdonalds france slaying it with these non pla...
# 10      McDonalds France launched a creative take on t...
# 11      Pendant que #McDonalds France bannit les paill...
# 12      #McDonalds France abandonne enfin les pailles ...
# 13      Sur une année, cette innovation va permettre d...
# 14      La paille en plastique chez #McDonalds France,...
# 15      #McDonalds France supprime les pailles dès ce ...
# ...

# %%
from wordcloud import WordCloud, STOPWORDS 
import sys,tweepy,csv,re
import matplotlib.pyplot as plt 
import pandas as pd 
  
from nltk.corpus import stopwords 
sp =stopwords.words('french','english')
comment_words = '' 
stopwords = set(STOPWORDS) 
sp2=list(stopwords)+sp+['http','https','bit','fr','was','com','to','of','are','or','gt','html','for','com','the','id','by']
  
# iterate through the csv file 
for val in tweets_df.text: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = sp2, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off")
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
tweets_df.to_csv("dataTwitterF.csv")

# %%
tweets_df
# Out:
#                           date  \
# 0    2019-12-21 06:01:13+00:00
# 1    2019-12-20 12:35:45+00:00
# 2    2019-12-20 06:07:57+00:00
# 3    2019-12-02 19:47:51+00:00
# 4    2019-12-02 19:06:35+00:00
# 5    2019-12-02 18:33:02+00:00
# 6    2019-12-02 14:02:10+00:00
# 7    2019-12-01 11:14:42+00:00
# 8    2019-11-27 20:56:42+00:00
# 9    2019-11-25 15:37:37+00:00
# 10   2019-11-21 20:02:01+00:00
# 11   2019-11-19 09:40:50+00:00
# 12   2019-11-19 09:13:22+00:00
# 13   2019-11-18 23:28:07+00:00
# 14   2019-11-18 17:37:04+00:00
# 15   2019-11-18 10:20:13+00:00
# 16   2019-11-18 06:06:40+00:00
# 17   2019-11-15 09:03:42+00:00
# 18   2019-11-14 23:58:27+00:00
# 19   2019-11-14 11:07:31+00:00
# 20   2019-11-10 11:33:33+00:00
# 21   2019-11-04 16:00:17+00:00
# 22   2019-11-02 18:44:53+00:00
# 23   2019-10-24 12:05:34+00:00
# 24   2019-10-16 11:44:15+00:00
# 25   2019-10-13 12:00:20+00:00
# 26   2019-10-09 17:16:52+00:00
# 27   2019-10-05 06:20:16+00:00
# 28   2019-10-03 07:27:44+00:00
# ...

# %%
import GetOldTweets3 as got

text_query = 'KFC France'
since_date = '2010-01-01'
until_date = '2019-12-31'
count = 2000
# Creation of query object
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setSince(since_date).setUntil(until_date).setMaxTweets(count)
# Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
# Creating list of chosen tweet data
text_tweets = [[tweet.date, tweet.text] for tweet in tweets]

# %%
import pandas as pd

kfc_df = pd.DataFrame(text_tweets, columns=['date','text'])
kfc_df.to_csv("dataKFC.csv")

# %%
kfc_df.head()
# Out:
#                        date                                               text
# 0 2019-12-30 22:09:50+00:00  @KFCFrance oui mais lui le poulet il ne la veu...
# 1 2019-12-30 20:09:10+00:00  @BurgerKingFR @KFCFrance Vous avez un endroit ...
# 2 2019-12-30 19:48:35+00:00                                         @KFCFrance
# 3 2019-12-30 19:13:09+00:00  @KFCFrance y’a pas de soucis perso jpense que ...
# 4 2019-12-30 18:46:24+00:00  Salutations @KFCFrance le ticket de 15 mètres ...

# %%
kfc_df.shape
# Out:
# (2000, 2)

# %%
import sys,tweepy,csv,re
from textblob import TextBlob
import matplotlib.pyplot as plt
